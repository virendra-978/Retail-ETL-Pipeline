# %%
# %sql
CREATE CATALOG IF NOT EXISTS bronze_catalog;
CREATE CATALOG IF NOT EXISTS silver_catalog;
CREATE CATALOG IF NOT EXISTS gold_catalog;

CREATE SCHEMA IF NOT EXISTS bronze_catalog.retail_bronze;
CREATE SCHEMA IF NOT EXISTS silver_catalog.retail_silver;
CREATE SCHEMA IF NOT EXISTS gold_catalog.retail_gold;
